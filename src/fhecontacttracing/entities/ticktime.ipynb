# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Seaborn
import seaborn as sns
sns.set(style="white", color_codes=True)
sns.set_context(rc={"font.family":'sans',"font.size":48,"axes.titlesize":24,"axes.labelsize":24,'figure.figsize':(20,20)})

# %%
firstticktime1 = pd.read_csv("/home/xopbat/Projects/Master Thesis/fhe-contact-tracing/results/1/usrcountsimfirsttick.txt")
firstticktime2 = pd.read_csv("/home/xopbat/Projects/Master Thesis/fhe-contact-tracing/results/2/usrcountsimfirsttick.txt")
firstticktime3 = pd.read_csv("/home/xopbat/Projects/Master Thesis/fhe-contact-tracing/results/3/usrcountsimfirsttick.txt")
firstticktimes = pd.concat([firstticktime1, firstticktime2, firstticktime3])

# %%
avgticktime1 = pd.read_csv("/home/xopbat/Projects/Master Thesis/fhe-contact-tracing/results/1/usrcountsimtick.txt")
avgticktime2 = pd.read_csv("/home/xopbat/Projects/Master Thesis/fhe-contact-tracing/results/2/usrcountsimtick.txt")
avgticktime3 = pd.read_csv("/home/xopbat/Projects/Master Thesis/fhe-contact-tracing/results/3/usrcountsimtick.txt")
avgticktimes = pd.concat([avgticktime1, avgticktime2, avgticktime3])

# %%
firstticktime1.describe()
# Out:
#              First  Count
# count     5.000000    5.0
# mean   1200.272121   10.0
# std      16.499331    0.0
# min    1181.327992   10.0
# 25%    1183.362617   10.0
# 50%    1209.732215   10.0
# 75%    1211.694404   10.0
# max    1215.243376   10.0

# %%
firstticktime2.describe()
# Out:
#              First  Count
# count     5.000000    5.0
# mean   2783.808161   15.0
# std     141.159274    0.0
# min    2601.869563   15.0
# 25%    2740.619171   15.0
# 50%    2778.709505   15.0
# 75%    2803.504401   15.0
# max    2994.338163   15.0

# %%
firstticktime3.describe()
# Out:
#              First  Count
# count     2.000000    2.0
# mean   5273.490171   20.0
# std     229.949265    0.0
# min    5110.891486   20.0
# 25%    5192.190828   20.0
# 50%    5273.490171   20.0
# 75%    5354.789513   20.0
# max    5436.088856   20.0

# %%
avgticktime1.describe()
# Out:
#               Tick  Count
# count    50.000000   50.0
# mean   1159.814092   10.0
# std      27.356674    0.0
# min    1059.652725   10.0
# 25%    1142.205462   10.0
# 50%    1156.342466   10.0
# 75%    1182.787229   10.0
# max    1208.497032   10.0

# %%
avgticktime2.describe()
# Out:
#               Tick  Count
# count    40.000000   40.0
# mean   2715.717866   15.0
# std     258.621977    0.0
# min    2305.964377   15.0
# 25%    2576.873862   15.0
# 50%    2658.859832   15.0
# 75%    2808.354626   15.0
# max    4037.279561   15.0

# %%
avgticktime3.describe()
# Out:
#               Tick  Count
# count    20.000000   20.0
# mean   4973.202264   20.0
# std     250.746534    0.0
# min    4470.794387   20.0
# 25%    4887.969862   20.0
# 50%    4957.598328   20.0
# 75%    5145.380532   20.0
# max    5374.119909   20.0

# %%
plt.figure(figsize=(20,20))
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 1})
ax = sns.boxplot(x="Count", y="First", data=firstticktimes)

# %%
plt.figure(figsize=(40,40))
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 1})
sns.set(font_scale=10)
ax = sns.boxplot(x="Count", y="Tick", data=avgticktimes)
